# %%
# !pip3 install pymongo
# !pip install dnspython
# !pip install bs4
# !pip install requests
# !pip install pandas
# !pip install lxml

# %%
from bs4 import BeautifulSoup
import requests
import pymongo
import os
from datetime import datetime
myclient = pymongo.MongoClient("mongodb+srv://crawler:!QAZ2wsx@cluster0.k1oua.mongodb.net/wear?retryWrites=true&w=majority")
db = myclient["wear"] #要連線的資料庫
collection = db["Mondel_W"] #連線到對應的資料集
headers = {
            "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
            "Accept-Encoding": "gzip, deflate, br", 
            "Accept-Language": "h-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7", 
            "Host": "wear.tw",  #目標網站 
            "Sec-Fetch-Dest": "document", 
            "Sec-Fetch-Mode": "navigate", 
            "Sec-Fetch-Site": "same-origin", 
            "Upgrade-Insecure-Requests": "1", 
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36", #使用者代理
            "Referer" : "https://wear.tw/ranking/user/" 
        }
#圖片類別
main_category_list = ["上衣","夾克／外套","褲子","裙子",'連衣裙／禮服裙','連體褲／背帶褲','泳裝／和服／夏季和服','居家服','正裝西服／小物','內衣']
other_category_list =[]
for cat in main_category_list:
    if not os.path.exists('./images/{}'.format(cat)): 
        os.mkdir('./images/{}'.format(cat))
exist = []
start = datetime.now()
for rank in range(2,12):
    print("Rank %s item pic downloading.."%(rank))
    my_json = collection.find_one({'Mondel_Rank':str(rank)}) 
    sta = datetime.now()
    for s in my_json['SET']:
        if 'ITEM' not in s:
            continue
        for i in s['ITEM']:
            #沒有Key
            if 'Jpg_Url' not in i:
                continue
            #沒上傳圖片的
            if 'ei_500.png' in i['Jpg_Url']:
                continue
            #沒上傳圖片的
            if 'ni_500.jpg' in i['Jpg_Url']:
                continue
            #排除Item_ID重複方式
            uniq_ID = '%s_%s'%(i['Item_Url'].split('/')[-3],i['Item_Url'].split('/')[-2])
            if os.path.exists('./images/{}/{}.jpg'.format(i['Body_Part'].replace('/','／'),uniq_ID)):
                continue
            #排除已經停用的商品
            res_404 = requests.get(i['Item_Url'],headers=headers)
            soup_404 = BeautifulSoup(res_404.text,'html.parser')
            if len(soup_404.select('div#notfound'))>0:
                continue
            #過濾掉重複引用的商品
            if uniq_ID not in exist:
                exist.append(uniq_ID)
                if i['Body_Part'].replace('/','／') in main_category_list:
                    res_img = requests.get(i['Jpg_Url'])
                    with open('./images/{}/{}.jpg'.format(i['Body_Part'].replace('/','／'),uniq_ID), 'wb') as f:
                            f.write(res_img.content)
                elif i['Body_Part'].replace('/','／') not in other_category_list:
                    other_category_list.append(i['Body_Part'].replace('/','／'))
    fin = datetime.now()
    print("Rank %s item pic complete.."%(rank))
    print('Rank %s Spend %s minutes.'%(rank,(fin-sta).seconds//60))
finish = datetime.now()
print('Total Spend %s minutes.'%((finish-start).seconds//60))
for other_cat in other_category_list:
    print('Other Categories:')
    print('\t%s'%(other_cat))
# Out:
# Rank 2 item pic downloading..

# %%
for other_cat in other_category_list:
    print(other_cat)
# Out:
# 包
# 鞋子
# 時尚配件
# 其他
# 連體褲/背帶褲
# 連衣裙/禮服裙
# 襪子
# 帽子
# 首飾
# 錢包/小物
# 手錶
# 內衣
# 頭飾
# 電腦・手機配件/家電
# 身體・頭髮護理
# 泳裝/和服/夏季和服
# 居家服
# 護膚
# 室內裝飾
# 餐具/廚房用品
# 雜貨/興趣愛好
# 底妝產品
# 音樂/書籍・雜誌
# 香氛
# 正裝西服/小物
# 化妝品
# 戶外/體育用品
# 母嬰用品
# DazyClair

# %%
from bs4 import BeautifulSoup
import requests
import pymongo
import os
from datetime import datetime
myclient = pymongo.MongoClient("mongodb+srv://crawler:!QAZ2wsx@cluster0.k1oua.mongodb.net/wear?retryWrites=true&w=majority")
db = myclient["wear"] #要連線的資料庫
collection = db["Mondel_W"] #連線到對應的資料集
headers = {
            "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
            "Accept-Encoding": "gzip, deflate, br", 
            "Accept-Language": "h-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7", 
            "Host": "wear.tw",  #目標網站 
            "Sec-Fetch-Dest": "document", 
            "Sec-Fetch-Mode": "navigate", 
            "Sec-Fetch-Site": "same-origin", 
            "Upgrade-Insecure-Requests": "1", 
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36", #使用者代理
            "Referer" : "https://wear.tw/ranking/user/" 
        }
main_category_list = ['連衣裙／禮服裙','連體褲／背帶褲','泳裝／和服／夏季和服','居家服','正裝西服／小物','內衣']
other_category_list =[]
for cat in main_category_list:
    if not os.path.exists('./{}'.format(cat)): 
        os.mkdir('./{}'.format(cat))
exist = []
start = datetime.now()
for rank in range(2,12):
    print("Rank %s item pic downloading.."%(rank),end='')
    my_json = collection.find_one({'Mondel_Rank':str(rank)}) 
    sta = datetime.now()
    for s in my_json['SET']:
        if 'ITEM' not in s:
            continue
        for i in s['ITEM']:
            if i['Body_Part'].replace('/','／') not in main_category_list:
                continue
            if 'Jpg_Url' not in i:
                continue
            if 'ei_500.png' in i['Jpg_Url']:
                continue
            if 'ni_500.jpg' in i['Jpg_Url']:
                continue
            uniq_ID = '%s_%s'%(i['Item_Url'].split('/')[-3],i['Item_Url'].split('/')[-2])
            if os.path.exists('./{}/{}.jpg'.format(i['Body_Part'].replace('/','／'),uniq_ID)):
                continue
            res_404 = requests.get(i['Item_Url'],headers=headers)
            soup_404 = BeautifulSoup(res_404.text,'html.parser')
            if len(soup_404.select('div#notfound'))>0:
                continue
            if uniq_ID not in exist:
                exist.append(i['Item_ID'])
                if i['Body_Part'].replace('/','／') in main_category_list:
                    res_img = requests.get(i['Jpg_Url'])
                    with open('./{}/{}.jpg'.format(i['Body_Part'].replace('/','／'),uniq_ID), 'wb') as f:
                            f.write(res_img.content)
                elif i['Body_Part'].replace('/','／') not in other_category_list:
                    other_category_list.append(i['Body_Part'].replace('/','／'))
    fin = datetime.now()
    print(" complete!!")
    print('Rank %s Spend %s minutes.'%(rank,(fin-sta).seconds//60))
finish = datetime.now()
print('Total Spend %s minutes.'%((finish-start).seconds//60))
print('Other Categories:')
for other_cat in other_category_list:
    print('\t%s'%(other_cat))
# Out:
# Rank 2 item pic downloading.. complete!!
# Rank 2 Spend 0 minutes.
# Rank 3 item pic downloading.. complete!!
# Rank 3 Spend 0 minutes.
# Rank 4 item pic downloading.. complete!!
# Rank 4 Spend 0 minutes.
# Rank 5 item pic downloading.. complete!!
# Rank 5 Spend 0 minutes.
# Rank 6 item pic downloading.. complete!!
# Rank 6 Spend 0 minutes.
# Rank 7 item pic downloading.. complete!!
# Rank 7 Spend 0 minutes.
# Rank 8 item pic downloading.. complete!!
# Rank 8 Spend 0 minutes.
# Rank 9 item pic downloading.. complete!!
# Rank 9 Spend 0 minutes.
# Rank 10 item pic downloading.. complete!!
# Rank 10 Spend 0 minutes.
# Rank 11 item pic downloading.. complete!!
# Rank 11 Spend 0 minutes.
# Total Spend 0 minutes.
# Other Categories:

# %%
from bs4 import BeautifulSoup
import requests
import pymongo
import os
from datetime import datetime
myclient = pymongo.MongoClient("mongodb+srv://crawler:!QAZ2wsx@cluster0.k1oua.mongodb.net/wear?retryWrites=true&w=majority")
db = myclient["wear"] #要連線的資料庫
collection = db["Mondel_M"] #連線到對應的資料集
headers = {
            "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9", 
            "Accept-Encoding": "gzip, deflate, br", 
            "Accept-Language": "h-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7", 
            "Host": "wear.tw",  #目標網站 
            "Sec-Fetch-Dest": "document", 
            "Sec-Fetch-Mode": "navigate", 
            "Sec-Fetch-Site": "same-origin", 
            "Upgrade-Insecure-Requests": "1", 
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36", #使用者代理
            "Referer" : "https://wear.tw/ranking/user/" 
        }
#圖片類別
main_category_list = []
other_category_list = []
for cat in main_category_list:
    if not os.path.exists('./{}'.format(cat)): 
        os.mkdir('./{}'.format(cat))
exist = []
start = datetime.now()
for rank in range(1,101):
    print("Rank %s item pic downloading.."%(rank),end='')
    my_json = collection.find_one({'Mondel_Rank':str(rank)}) 
    for s in my_json['SET']:
        if 'ITEM' not in s:
            continue
        for i in s['ITEM']:
            if i['Body_Part'].replace('/','／') not in main_category_list:
                main_category_list.append(i['Body_Part'].replace('/','／'))
            else:
                continue
print('All categories:')
for mc in main_category_list:
    print('\t%s'%(mc))
# Out:
# Rank 1 item pic downloading..Rank 2 item pic downloading..Rank 3 item pic downloading..Rank 4 item pic downloading..Rank 5 item pic downloading..Rank 6 item pic downloading..Rank 7 item pic downloading..Rank 8 item pic downloading..Rank 9 item pic downloading..Rank 10 item pic downloading..Rank 11 item pic downloading..Rank 12 item pic downloading..Rank 13 item pic downloading..Rank 14 item pic downloading..Rank 15 item pic downloading..Rank 16 item pic downloading..Rank 17 item pic downloading..Rank 18 item p